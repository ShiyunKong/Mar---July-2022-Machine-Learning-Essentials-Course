# %%
import requests as r

# %%
github = r.get('https://api.github.com/events')
encoding = github.encoding
text = github.text
content = github.content
json = github.json()

# %%
print(f"This is the encooding of the web: {encoding}")
print(f"\nThis is the text of the web:\n{text}")
print(f"\nThis is the content of the web:\n{content}")
# Out:
# This is the encooding of the web: utf-8
#
# This is the text of the web:
# [{"id":"22346622019","type":"CreateEvent","actor":{"id":107466936,"login":"guanweifang","display_login":"guanweifang","gravatar_id":"","url":"https://api.github.com/users/guanweifang","avatar_url":"https://avatars.githubusercontent.com/u/107466936?"},"repo":{"id":503678253,"name":"guanweifang/Test1005","url":"https://api.github.com/repos/guanweifang/Test1005"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2022-06-15T08:23:47Z"},{"id":"22346622697","type":"PushEvent","actor":{"id":388653,"login":"ameeno","display_login":"ameeno","gravatar_id":"","url":"https://api.github.com/users/ameeno","avatar_url":"https://avatars.githubusercontent.com/u/388653?"},"repo":{"id":286281680,"name":"ameeno/ameeno","url":"https://api.github.com/repos/ameeno/ameeno"},"payload":{"push_id":10166302263,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"53873d60879145bce36d7f817029fcbba96baecf","before":"2e3a1d7596c638f068be328da24c8e4deca6241c","commits":[{"sha":"53873d60879145bce36d7f817029fcbba96baecf","author":{"email":"41898282+github-actions[bot]@users.noreply.github.com","name":"readme-bot"},"message":"Updated with Dev Metrics","distinct":true,"url":"https://api.github.com/repos/ameeno/ameeno/commits/53873d60879145bce36d7f817029fcbba96baecf"}]},"public":true,"created_at":"2022-06-15T08:23:49Z"},{"id":"22346621658","type":"PushEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":133968906,"name":"bbc/simorgh","url":"https://api.github.com/repos/bbc/simorgh"},"payload":{"push_id":10166301777,"size":7,"distinct_size":1,"ref":"refs/heads/renovate/eslint-config-airbnb-19.x","head":"a77b518ee130021b99c5d223086c6dea23c9821d","before":"4e9733af05c93ff8b3bf8b65406f729136922486","commits":[{"sha":"e233c8e9d8b182aa7c806b7948fea19c724a7d6d","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"Topic Ads Spike","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/e233c8e9d8b182aa7c806b7948fea19c724a7d6d"},{"sha":"220c28009b7820d1913922d147a0c26cb9fd2d00","author":{"email":"99000097+ExcitedBlob@users.noreply.github.com","name":"ExcitedBlob"},"message":"Merge branch 'latest' into topic-ads-on-test","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/220c28009b7820d1913922d147a0c26cb9fd2d00"},{"sha":"a5fa5c2375ee5fcdb4f1d2766b06225efd03bad3","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"CR Feedback","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/a5fa5c2375ee5fcdb4f1d2766b06225efd03bad3"},{"sha":"37777956cd2c3701ed37cb6e2df3a4ac8ae6bfe2","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"Merge branch 'topic-ads-on-test' of github.com:bbc/simorgh into topic-ads-on-test","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/37777956cd2c3701ed37cb6e2df3a4ac8ae6bfe2"},{"sha":"4873e721e91013316553c0e012372d2af05a86bc","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"More tests","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/4873e721e91013316553c0e012372d2af05a86bc"},{"sha":"1568fe276d09b420dba9d1920ca9c8f4ad63de77","author":{"email":"99000097+ExcitedBlob@users.noreply.github.com","name":"ExcitedBlob"},"message":"Merge pull request #10149 from bbc/topic-ads-on-test\n\nEnable Topic Ads on Test Environment","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/1568fe276d09b420dba9d1920ca9c8f4ad63de77"},{"sha":"a77b518ee130021b99c5d223086c6dea23c9821d","author":{"email":"bot@renovateapp.com","name":"Renovate Bot"},"message":"chore(deps): update dependency eslint-config-airbnb to v19","distinct":true,"url":"https://api.github.com/repos/bbc/simorgh/commits/a77b518ee13 ...
#
# This is the content of the web:
# b'[{"id":"22346622019","type":"CreateEvent","actor":{"id":107466936,"login":"guanweifang","display_login":"guanweifang","gravatar_id":"","url":"https://api.github.com/users/guanweifang","avatar_url":"https://avatars.githubusercontent.com/u/107466936?"},"repo":{"id":503678253,"name":"guanweifang/Test1005","url":"https://api.github.com/repos/guanweifang/Test1005"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2022-06-15T08:23:47Z"},{"id":"22346622697","type":"PushEvent","actor":{"id":388653,"login":"ameeno","display_login":"ameeno","gravatar_id":"","url":"https://api.github.com/users/ameeno","avatar_url":"https://avatars.githubusercontent.com/u/388653?"},"repo":{"id":286281680,"name":"ameeno/ameeno","url":"https://api.github.com/repos/ameeno/ameeno"},"payload":{"push_id":10166302263,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"53873d60879145bce36d7f817029fcbba96baecf","before":"2e3a1d7596c638f068be328da24c8e4deca6241c","commits":[{"sha":"53873d60879145bce36d7f817029fcbba96baecf","author":{"email":"41898282+github-actions[bot]@users.noreply.github.com","name":"readme-bot"},"message":"Updated with Dev Metrics","distinct":true,"url":"https://api.github.com/repos/ameeno/ameeno/commits/53873d60879145bce36d7f817029fcbba96baecf"}]},"public":true,"created_at":"2022-06-15T08:23:49Z"},{"id":"22346621658","type":"PushEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":133968906,"name":"bbc/simorgh","url":"https://api.github.com/repos/bbc/simorgh"},"payload":{"push_id":10166301777,"size":7,"distinct_size":1,"ref":"refs/heads/renovate/eslint-config-airbnb-19.x","head":"a77b518ee130021b99c5d223086c6dea23c9821d","before":"4e9733af05c93ff8b3bf8b65406f729136922486","commits":[{"sha":"e233c8e9d8b182aa7c806b7948fea19c724a7d6d","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"Topic Ads Spike","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/e233c8e9d8b182aa7c806b7948fea19c724a7d6d"},{"sha":"220c28009b7820d1913922d147a0c26cb9fd2d00","author":{"email":"99000097+ExcitedBlob@users.noreply.github.com","name":"ExcitedBlob"},"message":"Merge branch \'latest\' into topic-ads-on-test","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/220c28009b7820d1913922d147a0c26cb9fd2d00"},{"sha":"a5fa5c2375ee5fcdb4f1d2766b06225efd03bad3","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"CR Feedback","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/a5fa5c2375ee5fcdb4f1d2766b06225efd03bad3"},{"sha":"37777956cd2c3701ed37cb6e2df3a4ac8ae6bfe2","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"Merge branch \'topic-ads-on-test\' of github.com:bbc/simorgh into topic-ads-on-test","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/37777956cd2c3701ed37cb6e2df3a4ac8ae6bfe2"},{"sha":"4873e721e91013316553c0e012372d2af05a86bc","author":{"email":"ryanmccombe3@gmail.com","name":"Ryan McCombe"},"message":"More tests","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/4873e721e91013316553c0e012372d2af05a86bc"},{"sha":"1568fe276d09b420dba9d1920ca9c8f4ad63de77","author":{"email":"99000097+ExcitedBlob@users.noreply.github.com","name":"ExcitedBlob"},"message":"Merge pull request #10149 from bbc/topic-ads-on-test\\n\\nEnable Topic Ads on Test Environment","distinct":false,"url":"https://api.github.com/repos/bbc/simorgh/commits/1568fe276d09b420dba9d1920ca9c8f4ad63de77"},{"sha":"a77b518ee130021b99c5d223086c6dea23c9821d","author":{"email":"bot@renovateapp.com","name":"Renovate Bot"},"message":"chore(deps): update dependency eslint-config-airbnb to v19","distinct":true,"url":"https://api.github.com/repos/bbc/simorgh/commits/a77 ...

# %%
from urllib.request import urlopen

# %%
url = "http://olympus.realpython.org/profiles/aphrodite"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
print(html)
# Out:
# <html>
# <head>
# <title>Profile: Aphrodite</title>
# </head>
# <body bgcolor="yellow">
# <center>
# <br><br>
# <img src="/static/aphrodite.gif" />
# <h2>Name: Aphrodite</h2>
# <br><br>
# Favorite animal: Dove
# <br><br>
# Favorite color: Red
# <br><br>
# Hometown: Mount Olympus
# </center>
# </body>
# </html>

# %%
title = html.find('<title>')
print(title)
# Out:
# 14
