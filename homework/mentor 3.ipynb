# %%
df = pd.DataFrame({
    "A": np.random.rann(50)+0.1,
    "B": np.random.rann(60 - 0.1)
})
df.sort_values(by = "B",  ascending=True)
df['C'] = [0]*50
df.loc[df["B"]>df["A"],"C"] = 1
df["D"] = df["C"].astype("catagory")

#plotting
df2 = df[df["C"] == 1]

fig, ax = plt.subplots(figsize = (10,5))
ax.scatter(df["A"],df["B"], c="blue", label = "A>B")
